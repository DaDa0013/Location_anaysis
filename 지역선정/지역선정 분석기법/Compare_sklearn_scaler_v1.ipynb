# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.style.use('fivethirtyeight')
# numpy float 출력옵션 변경
np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.3f}".format(x)})

# %%
print(plt.style.available)
plt.style.use('ggplot')
# %matplotlib inline
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# 랜덤에 의해 똑같은 결과를 재현하도록 seed값 고정
seed = 777
np.random.seed(seed)

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\82104\anaconda3\envs\ml\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('시군구_변수2 (2).xlsx')
df
# Out:
#     시군구  재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    총인구수  \
# 0   목포시   17.3  18.403979   1.528970  58.646693        117.755171  216551
# 1   여수시   29.3  20.934653   0.742100  49.157764         73.918711  274626
# 2   순천시   17.8  16.826932   0.546513  47.273704         72.343092  279225
# 3   나주시   16.8  23.296470   0.679426  50.935398         96.690926  115833
# 4   광양시   25.3  14.324758   0.775685  35.648506         38.949293  151479
# 5   담양군   10.7  32.426017   0.518259  50.083836        124.120811   45923
# 6   곡성군    8.3  37.925839   0.514498  58.799750        180.074235   27211
# 7   구례군    7.1  36.338436   0.626733  44.192680        148.648106   24891
# 8   고흥군    6.3  42.827717   0.560008  53.104181         49.885746   62142
# 9   보성군    7.0  40.589750   0.731393  74.684522         77.259851   38830
# 10  화순군   13.9  28.067184   0.900930  51.481708         46.655298   62158
# 11  장흥군    7.0  36.193999   0.784226  50.057009         77.866459   35959
# 12  강진군    7.8  36.533838   0.697199  48.082702         69.118884   33276
# 13  해남군    7.7  34.324667   0.526332  54.292091         28.654159   66308
# 14  영암군   10.8  28.059192   0.648833  39.840637         34.149118   52710
# 15  무안군   11.7  20.004177   0.455115  42.873161         15.390366   90966
# 16  함평군    7.6  38.692946   0.483013  48.625519         35.658714   30848
# 17  영광군   12.9  30.316820   0.664363  61.443932         19.201229   52080
# 18  장성군   11.2  31.949668   0.601291  41.788550         23.215861   43074
# 19  완도군    6.5  34.468850   0.376183  43.888065         20.899078   47849
# 20  진도군    8.5  35.345118   0.664598  47.230281         23.615141   29642
# 21  신안군    6.7  38.304987   0.313306  23.695435         13.164130   37982
#
#     기초생활수급자  안전상비의약품     자동차    10만면당 자동차수
# 0      3311      255  102292  47236.909550
# 1      2038      203  143418  52223.023312
# 2      1526      202  153944  55132.599158
# 3       787      112   75025  64769.970561
# 4      1175       59   93385  61648.809406
# 5       238       57   31480  68549.528559
# 6       140       49   18243  67042.740068
# 7       156       37   16530  66409.545619
# 8       348       31   38856  62527.759004
# 9       284       30   26600  68503.734226
# 10      560       29   36214  58261.205315
# 11      282       28   23366  64979.560055
# 12      232       23   22220  66774.852747
# 13      349       19   46778  70546.540387
# 14      342       18   39288  74536.141150
# 15      414       14   55157  60634.742651
# 16      149       11   22976  74481.327801
# 17      346       10   34564  66367.127496
# 18      259       10   30356  70474.067883
# 19      180       10   29103  60822.587724
# 20      197        7   19725  66544.092841
# 21      119        5   24988  65789.057975

# %%
print(df.keys())
# Out:
# Index(['시군구', '재정자립도', '노인인구비율', '기초생활수급자비율', '10만명당 약국수', '10만명당 안전상비의약품점포수',
#        '총인구수', '기초생활수급자', '안전상비의약품', '자동차', '10만면당 자동차수'],
#       dtype='object')

# %%
df.describe()
# Out:
#            재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수  \
# count  22.000000  22.000000  22.000000  22.000000         22.000000
# mean   11.736364  30.734363   0.651772  48.901188         63.056108
# std     6.225795   8.334377   0.240521  10.021058         46.255684
# min     6.300000  14.324758   0.313306  23.695435         13.164130
# 25%     7.225000  24.487150   0.520277  43.964218         24.874895
# 50%     9.600000  33.375342   0.637783  48.891641         48.270522
# 75%    13.650000  36.484988   0.722845  52.698563         77.714807
# max    29.300000  42.827717   1.528970  74.684522        180.074235
#
#                 총인구수      기초생활수급자     안전상비의약품            자동차    10만면당 자동차수
# count      22.000000    22.000000   22.000000      22.000000     22.000000
# mean    82707.409091   610.545455   55.409091   49295.818182  64284.360159
# std     77715.750267   777.597198   71.690246   39679.073703   6707.545121
# min     24891.000000   119.000000    5.000000   16530.000000  47236.909550
# 25%     36464.750000   205.750000   11.750000   23771.500000  61029.143144
# 50%     49964.500000   313.000000   28.500000   33022.000000  66078.092735
# 75%     84801.500000   523.500000   55.000000   53062.250000  68138.485687
# max    279225.000000  3311.000000  255.000000  153944.000000  74536.141150

# %%
df.dtypes
# Out:
# 시군구                  object
# 재정자립도               float64
# 노인인구비율              float64
# 기초생활수급자비율           float64
# 10만명당 약국수           float64
# 10만명당 안전상비의약품점포수    float64
# 총인구수                  int64
# 기초생활수급자               int64
# 안전상비의약품               int64
# 자동차                   int64
# 10만면당 자동차수          float64
# dtype: object

# %%
df.drop(["시군구", "총인구수", "기초생활수급자", "안전상비의약품", "자동차"], axis = 1)
# Out:
#     재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    10만면당 자동차수
# 0    17.3  18.403979   1.528970  58.646693        117.755171  47236.909550
# 1    29.3  20.934653   0.742100  49.157764         73.918711  52223.023312
# 2    17.8  16.826932   0.546513  47.273704         72.343092  55132.599158
# 3    16.8  23.296470   0.679426  50.935398         96.690926  64769.970561
# 4    25.3  14.324758   0.775685  35.648506         38.949293  61648.809406
# 5    10.7  32.426017   0.518259  50.083836        124.120811  68549.528559
# 6     8.3  37.925839   0.514498  58.799750        180.074235  67042.740068
# 7     7.1  36.338436   0.626733  44.192680        148.648106  66409.545619
# 8     6.3  42.827717   0.560008  53.104181         49.885746  62527.759004
# 9     7.0  40.589750   0.731393  74.684522         77.259851  68503.734226
# 10   13.9  28.067184   0.900930  51.481708         46.655298  58261.205315
# 11    7.0  36.193999   0.784226  50.057009         77.866459  64979.560055
# 12    7.8  36.533838   0.697199  48.082702         69.118884  66774.852747
# 13    7.7  34.324667   0.526332  54.292091         28.654159  70546.540387
# 14   10.8  28.059192   0.648833  39.840637         34.149118  74536.141150
# 15   11.7  20.004177   0.455115  42.873161         15.390366  60634.742651
# 16    7.6  38.692946   0.483013  48.625519         35.658714  74481.327801
# 17   12.9  30.316820   0.664363  61.443932         19.201229  66367.127496
# 18   11.2  31.949668   0.601291  41.788550         23.215861  70474.067883
# 19    6.5  34.468850   0.376183  43.888065         20.899078  60822.587724
# 20    8.5  35.345118   0.664598  47.230281         23.615141  66544.092841
# 21    6.7  38.304987   0.313306  23.695435         13.164130  65789.057975

# %%
train_data = df.drop(["시군구", "총인구수", "기초생활수급자", "안전상비의약품", "자동차"], axis = 1)
train_data
# Out:
#     재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    10만면당 자동차수
# 0    17.3  18.403979   1.528970  58.646693        117.755171  47236.909550
# 1    29.3  20.934653   0.742100  49.157764         73.918711  52223.023312
# 2    17.8  16.826932   0.546513  47.273704         72.343092  55132.599158
# 3    16.8  23.296470   0.679426  50.935398         96.690926  64769.970561
# 4    25.3  14.324758   0.775685  35.648506         38.949293  61648.809406
# 5    10.7  32.426017   0.518259  50.083836        124.120811  68549.528559
# 6     8.3  37.925839   0.514498  58.799750        180.074235  67042.740068
# 7     7.1  36.338436   0.626733  44.192680        148.648106  66409.545619
# 8     6.3  42.827717   0.560008  53.104181         49.885746  62527.759004
# 9     7.0  40.589750   0.731393  74.684522         77.259851  68503.734226
# 10   13.9  28.067184   0.900930  51.481708         46.655298  58261.205315
# 11    7.0  36.193999   0.784226  50.057009         77.866459  64979.560055
# 12    7.8  36.533838   0.697199  48.082702         69.118884  66774.852747
# 13    7.7  34.324667   0.526332  54.292091         28.654159  70546.540387
# 14   10.8  28.059192   0.648833  39.840637         34.149118  74536.141150
# 15   11.7  20.004177   0.455115  42.873161         15.390366  60634.742651
# 16    7.6  38.692946   0.483013  48.625519         35.658714  74481.327801
# 17   12.9  30.316820   0.664363  61.443932         19.201229  66367.127496
# 18   11.2  31.949668   0.601291  41.788550         23.215861  70474.067883
# 19    6.5  34.468850   0.376183  43.888065         20.899078  60822.587724
# 20    8.5  35.345118   0.664598  47.230281         23.615141  66544.092841
# 21    6.7  38.304987   0.313306  23.695435         13.164130  65789.057975

# %%
corr = train_data.corr()

# %%
plt.figure(figsize=(20,15))

# %%
from matplotlib import font_manager, rc

import matplotlib

font_location='c:/Windows/fonts/malgun.ttf'

font_name=font_manager.FontProperties(fname=font_location).get_name()

matplotlib.rc('font',family=font_name)

# %%
mask = np.zeros_like(corr,dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_18264\519181320.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr,dtype=np.bool)

# %%
sns.heatmap(data=corr, 
           annot = True,
           mask=mask,
           fmt='.2f',
           linewidths=1,
           cmap='RdYlBu_r')
plt.show()
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %matplotlib inline
df['재정자립도'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['노인인구비율'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['기초생활수급자비율'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['10만명당 약국수'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['10만명당 안전상비의약품점포수'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
df['10만면당 자동차수'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(train_data.keys())
# Out:
# Index(['재정자립도', '노인인구비율', '기초생활수급자비율', '10만명당 약국수', '10만명당 안전상비의약품점포수',
#        '10만면당 자동차수'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    10만면당 자동차수
# 0   17.3  18.403979   1.528970  58.646693        117.755171  47236.909550
# 1   29.3  20.934653   0.742100  49.157764         73.918711  52223.023312
# 2   17.8  16.826932   0.546513  47.273704         72.343092  55132.599158
# 3   16.8  23.296470   0.679426  50.935398         96.690926  64769.970561
# 4   25.3  14.324758   0.775685  35.648506         38.949293  61648.809406

# %%
from sklearn.preprocessing import MinMaxScaler
minMaxScaler = MinMaxScaler()
# %time print(minMaxScaler.fit(train_data))
train_data_minMaxScaled =  pd.DataFrame(minMaxScaler.transform(train_data), columns= train_data.keys())

from sklearn.preprocessing import MaxAbsScaler
maxAbsScaler = MaxAbsScaler()
# %time print(maxAbsScaler.fit(train_data))
train_data_maxAbsScaled = pd.DataFrame(maxAbsScaler.transform(train_data), columns=train_data.keys())

from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
# %time print(standardScaler.fit(train_data))
train_data_standardScaled = pd.DataFrame(standardScaler.transform(train_data), columns=train_data.keys())

from sklearn.preprocessing import RobustScaler
robustScaler = RobustScaler()
# %time print(robustScaler.fit(train_data))
train_data_robustScaled = pd.DataFrame(robustScaler.transform(train_data), columns=train_data.keys())
# Out:
# MinMaxScaler()
# CPU times: total: 0 ns
# Wall time: 2.9 ms
# MaxAbsScaler()
# CPU times: total: 0 ns
# Wall time: 1.04 ms
# StandardScaler()
# CPU times: total: 0 ns
# Wall time: 2 ms
# RobustScaler()
# CPU times: total: 0 ns
# Wall time: 8.09 ms

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols = 6, figsize =(20, 5))
sns.kdeplot(train_data_minMaxScaled['재정자립도'], ax = ax1, color ='r')
sns.kdeplot(train_data_minMaxScaled['노인인구비율'], ax = ax2, color ='r')
sns.kdeplot(train_data_minMaxScaled['기초생활수급자비율'], ax = ax3, color ='r')
sns.kdeplot(train_data_minMaxScaled['10만명당 약국수'], ax = ax4, color ='r')
sns.kdeplot(train_data_minMaxScaled['10만명당 안전상비의약품점포수'], ax = ax5, color ='r')
sns.kdeplot(train_data_minMaxScaled['10만면당 자동차수'], ax = ax6, color ='r')

plt.show()

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols = 6, figsize =(20, 5))
sns.kdeplot(train_data_maxAbsScaled['재정자립도'], ax = ax1, color ='r')
sns.kdeplot(train_data_maxAbsScaled['노인인구비율'], ax = ax2, color ='r')
sns.kdeplot(train_data_maxAbsScaled['기초생활수급자비율'], ax = ax3, color ='r')
sns.kdeplot(train_data_maxAbsScaled['10만명당 약국수'], ax = ax4, color ='r')
sns.kdeplot(train_data_maxAbsScaled['10만명당 안전상비의약품점포수'], ax = ax5, color ='r')
sns.kdeplot(train_data_maxAbsScaled['10만면당 자동차수'], ax = ax6, color ='r')

plt.show()


fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols = 6, figsize =(20, 5))
sns.kdeplot(train_data_standardScaled['재정자립도'], ax = ax1, color ='r')
sns.kdeplot(train_data_standardScaled['노인인구비율'], ax = ax2, color ='r')
sns.kdeplot(train_data_standardScaled['기초생활수급자비율'], ax = ax3, color ='r')
sns.kdeplot(train_data_standardScaled['10만명당 약국수'], ax = ax4, color ='r')
sns.kdeplot(train_data_standardScaled['10만명당 안전상비의약품점포수'], ax = ax5, color ='r')
sns.kdeplot(train_data_standardScaled['10만면당 자동차수'], ax = ax6, color ='r')

plt.show()

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols = 6, figsize =(20, 5))
sns.kdeplot(train_data_robustScaled['재정자립도'], ax = ax1, color ='r')
sns.kdeplot(train_data_robustScaled['노인인구비율'], ax = ax2, color ='r')
sns.kdeplot(train_data_robustScaled['기초생활수급자비율'], ax = ax3, color ='r')
sns.kdeplot(train_data_robustScaled['10만명당 약국수'], ax = ax4, color ='r')
sns.kdeplot(train_data_robustScaled['10만명당 안전상비의약품점포수'], ax = ax5, color ='r')
sns.kdeplot(train_data_robustScaled['10만면당 자동차수'], ax = ax6, color ='r')

plt.show()
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in c:\users\82104\anaconda3\envs\ml\lib\site-packages (1.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from yellowbrick) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from yellowbrick) (3.5.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from yellowbrick) (1.22.3)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\82104\anaconda3\envs\ml\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(train_data_minMaxScaled)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(train_data_maxAbsScaled)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(train_data_standardScaled)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(train_data_robustScaled)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
from sklearn.decomposition import PCA
# PCA 주성분분석
pca = PCA(random_state=1107)
X_p = pca.fit_transform(train_data_minMaxScaled)
pd.Series(np.cumsum(pca.explained_variance_ratio_))
# Out:
# 0    0.505940
# 1    0.760009
# 2    0.860400
# 3    0.928193
# 4    0.971169
# 5    1.000000
# dtype: float64

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
columns = []
for i in range(len(percent_variance)):
    columns.append(f'PC{i+1}')
    

ax = plt.bar(x = range(len(percent_variance)), height=percent_variance, tick_label=columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %%
# X_pp = pd.DataFrame(X_p[:,:4], columns = ['PC1','PC2','PC3', 'PC4'], index = df['시군구'])
# X_pp

X_pp = pd.DataFrame(X_p[:,:3], columns = ['PC1','PC2','PC3'], index = df['시군구'])
X_pp
# Out:
#           PC1       PC2       PC3
# 시군구
# 목포시  0.909101  0.512633  0.339658
# 여수시  0.876400 -0.021802 -0.063825
# 순천시  0.588725 -0.080388 -0.120708
# 나주시  0.302007  0.107312 -0.176691
# 광양시  0.758844 -0.372648 -0.194910
# 담양군 -0.134148  0.276099 -0.276667
# 곡성군 -0.265141  0.681180 -0.302350
# 구례군 -0.236022  0.427713 -0.297192
# 고흥군 -0.397879  0.072520  0.195709
# 보성군 -0.386019  0.378150  0.304338
# 화순군  0.258781 -0.003544  0.216440
# 장흥군 -0.212472  0.171717  0.080560
# 강진군 -0.252834  0.082854  0.029407
# 해남군 -0.328803 -0.136304  0.104533
# 영암군 -0.147626 -0.281389 -0.129463
# 무안군  0.229717 -0.391041 -0.005309
# 함평군 -0.496956 -0.144779 -0.012764
# 영광군 -0.018482 -0.125737  0.245696
# 장성군 -0.171384 -0.283678 -0.021176
# 완도군 -0.233807 -0.243273  0.089727
# 진도군 -0.234518 -0.165765  0.149935
# 신안군 -0.407483 -0.459829 -0.154948

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(X_pp)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
# Minmax 군집 3개
from sklearn.cluster import KMeans
k = 3
model = KMeans(n_clusters = k, random_state = 10)
model.fit(X_pp)
df['cluster'] = model.fit_predict(X_pp)

# %%
df
# Out:
#     시군구  재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    총인구수  \
# 0   목포시   17.3  18.403979   1.528970  58.646693        117.755171  216551
# 1   여수시   29.3  20.934653   0.742100  49.157764         73.918711  274626
# 2   순천시   17.8  16.826932   0.546513  47.273704         72.343092  279225
# 3   나주시   16.8  23.296470   0.679426  50.935398         96.690926  115833
# 4   광양시   25.3  14.324758   0.775685  35.648506         38.949293  151479
# 5   담양군   10.7  32.426017   0.518259  50.083836        124.120811   45923
# 6   곡성군    8.3  37.925839   0.514498  58.799750        180.074235   27211
# 7   구례군    7.1  36.338436   0.626733  44.192680        148.648106   24891
# 8   고흥군    6.3  42.827717   0.560008  53.104181         49.885746   62142
# 9   보성군    7.0  40.589750   0.731393  74.684522         77.259851   38830
# 10  화순군   13.9  28.067184   0.900930  51.481708         46.655298   62158
# 11  장흥군    7.0  36.193999   0.784226  50.057009         77.866459   35959
# 12  강진군    7.8  36.533838   0.697199  48.082702         69.118884   33276
# 13  해남군    7.7  34.324667   0.526332  54.292091         28.654159   66308
# 14  영암군   10.8  28.059192   0.648833  39.840637         34.149118   52710
# 15  무안군   11.7  20.004177   0.455115  42.873161         15.390366   90966
# 16  함평군    7.6  38.692946   0.483013  48.625519         35.658714   30848
# 17  영광군   12.9  30.316820   0.664363  61.443932         19.201229   52080
# 18  장성군   11.2  31.949668   0.601291  41.788550         23.215861   43074
# 19  완도군    6.5  34.468850   0.376183  43.888065         20.899078   47849
# 20  진도군    8.5  35.345118   0.664598  47.230281         23.615141   29642
# 21  신안군    6.7  38.304987   0.313306  23.695435         13.164130   37982
#
#     기초생활수급자  안전상비의약품     자동차    10만면당 자동차수  cluster
# 0      3311      255  102292  47236.909550        0
# 1      2038      203  143418  52223.023312        0
# 2      1526      202  153944  55132.599158        0
# 3       787      112   75025  64769.970561        0
# 4      1175       59   93385  61648.809406        0
# 5       238       57   31480  68549.528559        2
# 6       140       49   18243  67042.740068        2
# 7       156       37   16530  66409.545619        2
# 8       348       31   38856  62527.759004        1
# 9       284       30   26600  68503.734226        2
# 10      560       29   36214  58261.205315        0
# 11      282       28   23366  64979.560055        2
# 12      232       23   22220  66774.852747        1
# 13      349       19   46778  70546.540387        1
# 14      342       18   39288  74536.141150        1
# 15      414       14   55157  60634.742651        0
# 16      149       11   22976  74481.327801        1
# 17      346       10   34564  66367.127496        1
# 18      259       10   30356  70474.067883        1
# 19      180       10   29103  60822.587724        1
# 20      197        7   19725  66544.092841        1
# 21      119        5   24988  65789.057975        1

# %%
df[['시군구','cluster']].sort_values('cluster')
# Out:
#     시군구  cluster
# 0   목포시        0
# 15  무안군        0
# 4   광양시        0
# 10  화순군        0
# 2   순천시        0
# 1   여수시        0
# 3   나주시        0
# 19  완도군        1
# 18  장성군        1
# 17  영광군        1
# 16  함평군        1
# 14  영암군        1
# 13  해남군        1
# 12  강진군        1
# 20  진도군        1
# 8   고흥군        1
# 21  신안군        1
# 9   보성군        2
# 7   구례군        2
# 6   곡성군        2
# 5   담양군        2
# 11  장흥군        2

# %%
from sklearn.decomposition import PCA
# PCA 주성분분석
pca = PCA(random_state=1107)
X_p = pca.fit_transform(train_data_standardScaled)
pd.Series(np.cumsum(pca.explained_variance_ratio_))
# Out:
# 0    0.460863
# 1    0.731698
# 2    0.842497
# 3    0.917340
# 4    0.976443
# 5    1.000000
# dtype: float64

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
columns = []
for i in range(len(percent_variance)):
    columns.append(f'PC{i+1}')
    

ax = plt.bar(x = range(len(percent_variance)), height=percent_variance, tick_label=columns)
plt.ylabel('Percentate of Variance Explained')
plt.xlabel('Principal Component')
plt.title('PCA Scree Plot')
plt.show()

# %%
# X_pp = pd.DataFrame(X_p[:,:4], columns = ['PC1','PC2','PC3', 'PC4'], index = df['시군구'])
# X_pp

X_pp = pd.DataFrame(X_p[:,:3], columns = ['PC1','PC2','PC3'], index = df['시군구'])
X_pp
# Out:
#           PC1       PC2       PC3
# 시군구
# 목포시  4.406541  1.981476 -0.668414
# 여수시  3.252660 -0.689199  0.372943
# 순천시  1.930460 -0.853117  0.567573
# 나주시  1.027876  0.138170  0.620167
# 광양시  2.474237 -2.098067  0.332990
# 담양군 -0.583697  0.734507  1.235897
# 곡성군 -0.807897  2.299901  1.761104
# 구례군 -0.738629  1.074837  1.677379
# 고흥군 -1.274443  0.628657 -0.487071
# 보성군 -1.005793  2.550264 -1.172036
# 화순군  1.244870  0.165991 -0.758085
# 장흥군 -0.509903  0.821293 -0.106999
# 강진군 -0.799862  0.434119 -0.023629
# 해남군 -1.354289  0.021334 -0.742715
# 영암군 -0.851291 -1.056971 -0.049936
# 무안군  0.419929 -1.660449 -0.224897
# 함평군 -2.038245 -0.182088 -0.310301
# 영광군 -0.062990  0.258581 -1.343140
# 장성군 -0.856168 -0.994630 -0.306532
# 완도군 -1.076404 -0.923375 -0.254913
# 진도군 -0.845999 -0.302127 -0.734506
# 신안군 -1.950963 -2.349109  0.615120

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model,k=(1,10))
visualizer.fit(X_pp)
# Out:
# C:\Users\82104\anaconda3\envs\ml\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(1, 10))

# %%
# standard 군집 4개
from sklearn.cluster import KMeans
k = 3
model = KMeans(n_clusters = k, random_state = 10)
model.fit(X_pp)
df['cluster'] = model.fit_predict(X_pp)

# %%
df
# Out:
#     시군구  재정자립도     노인인구비율  기초생활수급자비율  10만명당 약국수  10만명당 안전상비의약품점포수    총인구수  \
# 0   목포시   17.3  18.403979   1.528970  58.646693        117.755171  216551
# 1   여수시   29.3  20.934653   0.742100  49.157764         73.918711  274626
# 2   순천시   17.8  16.826932   0.546513  47.273704         72.343092  279225
# 3   나주시   16.8  23.296470   0.679426  50.935398         96.690926  115833
# 4   광양시   25.3  14.324758   0.775685  35.648506         38.949293  151479
# 5   담양군   10.7  32.426017   0.518259  50.083836        124.120811   45923
# 6   곡성군    8.3  37.925839   0.514498  58.799750        180.074235   27211
# 7   구례군    7.1  36.338436   0.626733  44.192680        148.648106   24891
# 8   고흥군    6.3  42.827717   0.560008  53.104181         49.885746   62142
# 9   보성군    7.0  40.589750   0.731393  74.684522         77.259851   38830
# 10  화순군   13.9  28.067184   0.900930  51.481708         46.655298   62158
# 11  장흥군    7.0  36.193999   0.784226  50.057009         77.866459   35959
# 12  강진군    7.8  36.533838   0.697199  48.082702         69.118884   33276
# 13  해남군    7.7  34.324667   0.526332  54.292091         28.654159   66308
# 14  영암군   10.8  28.059192   0.648833  39.840637         34.149118   52710
# 15  무안군   11.7  20.004177   0.455115  42.873161         15.390366   90966
# 16  함평군    7.6  38.692946   0.483013  48.625519         35.658714   30848
# 17  영광군   12.9  30.316820   0.664363  61.443932         19.201229   52080
# 18  장성군   11.2  31.949668   0.601291  41.788550         23.215861   43074
# 19  완도군    6.5  34.468850   0.376183  43.888065         20.899078   47849
# 20  진도군    8.5  35.345118   0.664598  47.230281         23.615141   29642
# 21  신안군    6.7  38.304987   0.313306  23.695435         13.164130   37982
#
#     기초생활수급자  안전상비의약품     자동차    10만면당 자동차수  cluster
# 0      3311      255  102292  47236.909550        1
# 1      2038      203  143418  52223.023312        1
# 2      1526      202  153944  55132.599158        1
# 3       787      112   75025  64769.970561        1
# 4      1175       59   93385  61648.809406        1
# 5       238       57   31480  68549.528559        0
# 6       140       49   18243  67042.740068        0
# 7       156       37   16530  66409.545619        0
# 8       348       31   38856  62527.759004        2
# 9       284       30   26600  68503.734226        0
# 10      560       29   36214  58261.205315        1
# 11      282       28   23366  64979.560055        0
# 12      232       23   22220  66774.852747        2
# 13      349       19   46778  70546.540387        2
# 14      342       18   39288  74536.141150        2
# 15      414       14   55157  60634.742651        2
# 16      149       11   22976  74481.327801        2
# 17      346       10   34564  66367.127496        2
# 18      259       10   30356  70474.067883        2
# 19      180       10   29103  60822.587724        2
# 20      197        7   19725  66544.092841        2
# 21      119        5   24988  65789.057975        2

# %%
df[['시군구','cluster']].sort_values('cluster')
# Out:
#     시군구  cluster
# 11  장흥군        0
# 9   보성군        0
# 7   구례군        0
# 6   곡성군        0
# 5   담양군        0
# 0   목포시        1
# 10  화순군        1
# 3   나주시        1
# 2   순천시        1
# 1   여수시        1
# 4   광양시        1
# 8   고흥군        2
# 20  진도군        2
# 12  강진군        2
# 13  해남군        2
# 14  영암군        2
# 15  무안군        2
# 16  함평군        2
# 17  영광군        2
# 18  장성군        2
# 19  완도군        2
# 21  신안군        2
