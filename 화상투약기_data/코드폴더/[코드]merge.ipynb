# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
path='/content/drive/Shareddrives/데청캠/화상투약기_data/전국약국데이터/'

# %%
import os
region = os.listdir(path)
region
# Out:
# ['인천광역시.csv',
#  '광주광역시.csv',
#  '대전광역시.csv',
#  '울산광역시.csv',
#  '세종특별자치시.csv',
#  '제주특별자치도.csv',
#  '경기도.csv',
#  '강원도.csv',
#  '경상남도.csv',
#  '경상북도.csv',
#  '부산광역시.csv',
#  '서울특별시.csv',
#  '충정남도.csv',
#  '충청북도.csv',
#  '전라남도.csv',
#  '전라북도.csv',
#  '대구광역시.csv']

# %%
df_all = pd.DataFrame()

for files in region:
    df= pd.read_csv(path + files, dtype={"주소":str})
    df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df_all[690:710] # 겹치는 부분 확인
# Out:
#       NO          약국명          대표전화  \
# 690  691        신보건약국  032-865-0407
# 691  692         나음약국  032-555-8582
# 692  693        새오개약국  032-571-5553
# 693  694        성누가약국  032-565-5250
# 694  695       용현우리약국  032-888-8876
# 695  696   모래내시장역미래약국  032-467-7730
# 696  697         우리약국  032-546-4640
# 697  698      아라온누리약국  032-545-0677
# 698  699       태영스타약국  032-752-7562
# 699  700  w-store보듬약국  032-751-0660
# 700  701     옵티마프라자약국  032-743-6789
# 701  702         다온약국  032-433-0112
# 702  703        비타민약국  032-887-5707
# 703  704     비타민온누리약국  032-545-0102
# 704  705         삼호약국  032-813-0530
# 705  706      연수태평양약국  032-818-7010
# 706  707        미래팜약국  032-833-4350
# 707  708         열린약국  032-812-8611
# 708  709      경서메디칼약국  032-562-4001
# 709  710         소원약국  032-512-5133
#
#                                             주소       월요일 운영       화요일 운영  \
# 690             인천광역시 미추홀구 주안서로 26-1, 1층 (주안동)  09:00~18:00  09:00~18:00
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23541 entries, 0 to 23540
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NO      23541 non-null  int64
#  1   약국명     23541 non-null  object
#  2   대표전화    23539 non-null  object
#  3   주소      23541 non-null  object
#  4   월요일 운영  23541 non-null  object
#  5   화요일 운영  23541 non-null  object
#  6   수요일 운영  23541 non-null  object
#  7   목요일 운영  23541 non-null  object
#  8   금요일 운영  23541 non-null  object
#  9   토요일 운영  23541 non-null  object
#  10  일요일 운영  23541 non-null  object
#  11  공휴일 운영  23541 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.2+ MB

# %% [markdown]
# ---

# %%
df_all = pd.DataFrame()

for files in region:
    df= pd.read_csv(path + files, dtype={"주소":str})
    df_all = pd.concat([df_all, df], ignore_index=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23541 entries, 0 to 23540
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NO      23541 non-null  int64
#  1   약국명     23541 non-null  object
#  2   대표전화    23539 non-null  object
#  3   주소      23541 non-null  object
#  4   월요일 운영  23541 non-null  object
#  5   화요일 운영  23541 non-null  object
#  6   수요일 운영  23541 non-null  object
#  7   목요일 운영  23541 non-null  object
#  8   금요일 운영  23541 non-null  object
#  9   토요일 운영  23541 non-null  object
#  10  일요일 운영  23541 non-null  object
#  11  공휴일 운영  23541 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.2+ MB

# %%
import requests
from urllib.parse import urlparse

# %%
# 주소 -> 좌표변환 (주소문자열에서 괄호를 포함한 부분 제거 필요)
import requests
from urllib.parse import urlparse
address = '서울특별시 마포구 백범로 178, A203-1호 (공덕동, 마포신영지웰)'
url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
result = requests.get(urlparse(url).geturl(),headers={'Authorization':'KakaoAK 0c735c141d1b40f48aa11015f53f0526'}).json()
match_first = result['documents'][0]['address']
lat = float(match_first['y'])
lng = float(match_first['x'])
print(lat, lng)
# Out:
# 37.5438817651664 126.950076196083

# %%
def get_coordinate(address) :
  url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
  result = requests.get(urlparse(url).geturl(),headers={'Authorization':'KakaoAK 0c735c141d1b40f48aa11015f53f0526'}).json()
  match_first = result['documents'][0]['address']
  lat = float(match_first['y'])
  lng = float(match_first['x'])
  return(lat, lng)

# %% [markdown]
# lat: y좌표
#
# lng: x좌표

# %%
df_all.loc[:,"lat"]=0
df_all.loc[:,'lng']=0

# %%
seoul_ds.tail(1).T
print(seoul_ds[seoul_ds["주소"]].str.contain("~", regex=False))

# %%
for add in range(100) :
  try:
    df_all.loc[add,"lat"], df_all.loc[add,"lng"] = get_coordinate(df_all.loc[add,"주소"])
  except:
    df_all.loc[add,"lat"], df_all.loc[add,"lng"] = None,None

# %%
seoul_ds.loc[0,"주소"]
# seoul_ds.at[0,"lat"]

# %%
np.shape(seoul_ds)[0]
